# %% [markdown]
# # <a id='toc1_'></a>[Key items for this class: <span style="color:red">numerical</span>, <span style="color:orange">categorical</span>, <span style="color:yellow">continuous</span>, <span style="color:green">discrete</span>, <span style="color:blue">percentile</span>, <span style="color:purple">outlier</span> + more terminology](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Key items for this class: <span style="color:red">numerical</span>, <span style="color:orange">categorical</span>, <span style="color:yellow">continuous</span>, <span style="color:green">discrete</span>, <span style="color:blue">percentile</span>, <span style="color:purple">outlier</span> + more terminology](#toc1_)
# - [What's EDA?](#toc2_)
# - [Why is EDA important?](#toc3_)
# - [<span style="color:orange">Attention: Data visualization is qualitative, not quantitative! Many insights (errors, correlations) that you get from plots need to be confirmed using statistical methods or calculations!</span>](#toc4_)
# - [How do we EDA?](#toc5_)
#   - [Software](#toc5_1_)
#   - [Plots / Charts](#toc5_2_)
#   - [Methodology](#toc5_3_)
# - [Let the EDA begin](#toc6_)
#   - [Histogram](#toc6_1_)
#   - [Box plot](#toc6_2_)
#   - [Bar plots](#toc6_3_)
#   - [~~Pie charts~~](#toc6_4_)
#   - [Scatter plot](#toc6_5_)
#   - [Line plot](#toc6_6_)
#   - [💡 Check for understanding](#toc6_7_)
#   - [Common mistakes!](#toc6_8_)
#     - [Plotting without understanding what you're plotting (e.g. `customer_id`)](#toc6_8_1_)
#     - [Doing barplots for numerical continuous data](#toc6_8_2_)
#     - [Doing boxplots for numerical discrete data](#toc6_8_3_)
#     - [Considering histograms on numerical discrete data as normal distributions](#toc6_8_4_)
#     - [Creating noisy plots](#toc6_8_5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc2_'></a>[What's EDA?](#toc0_)

# %% [markdown]
# > **Exploratory data analysis (EDA) is a process of examining and summarizing data sets** without making any formal assumptions or hypotheses. It helps to understand the structure, patterns, variability, and relationships in data, as well as identify potential problems or anomalies.
#
# > It can be carried out at various stages of the data analytics process, but it is usually conducted before a firm hypothesis or end goal is defined.

# %% [markdown]
# # <a id='toc3_'></a>[Why is EDA important?](#toc0_)

# %% [markdown]
# > It can be used for:
# > + data cleaning
# > + subgroup analyses
# > + understanding data better
#
# > It aims to:
# > + spot patterns and trends
# > + identify anomalies
# > + test early hypotheses

# %% [markdown]
# *Example:* A scatterplot can show us different "clusters" or groups (i.e. concentrations of data points)
#
# ![clusters](https://imgs.search.brave.com/OzO3GC6FI7JzvoZX8LzeAqso6bjk7bw-H5XwqOdrt00/rs:fit:860:0:0/g:ce/aHR0cHM6Ly9kM21t/MnM5cjE1aXFjdi5j/bG91ZGZyb250Lm5l/dC9lbi93cC1jb250/ZW50L3VwbG9hZHMv/b2xkLWJsb2ctdXBs/b2Fkcy81MDBweC1z/bGluay1nYXVzc2lh/bi1kYXRhLnBuZw)

# %% [markdown]
# *Example:* A lineplot can show us how one variable is connected to another
#
# ![lineplot](https://imgs.search.brave.com/m8MYbCLtnAGWF1zDpGJa7_pQ0ARO2bWGHlFss-Siet4/rs:fit:860:0:0/g:ce/aHR0cHM6Ly9pMC53/cC5jb20vc3RhdGlz/dGljc2J5amltLmNv/bS93cC1jb250ZW50/L3VwbG9hZHMvMjAx/OS8xMC9vdXRsaWVy/X2NpcmNsZWQucG5n/P3Jlc2l6ZT01NzYs/MzgzJnNzbD0x)

# %% [markdown]
# *Example:* A boxplot can show us if our data has outliers or not
#
# ![outliers](https://imgs.search.brave.com/OWWypOQK8IXV4gq9m6mBUQHpZ7Y9Bi0-tdtwHhulMnk/rs:fit:860:0:0/g:ce/aHR0cHM6Ly9tZWRp/YS5nZWVrc2Zvcmdl/ZWtzLm9yZy93cC1j/b250ZW50L3VwbG9h/ZHMvMjAyMTA3MDcy/MzMyMjIvb3V0bGll/cnNFREEucG5n)

# %% [markdown]
# # <a id='toc4_'></a>[<span style="color:orange">Attention: Data visualization is qualitative, not quantitative! Many insights (errors, correlations) that you get from plots need to be confirmed using statistical methods or calculations!</span>](#toc0_)

# %% [markdown]
# # <a id='toc5_'></a>[How do we EDA?](#toc0_)

# %% [markdown]
# ## <a id='toc5_1_'></a>[Software](#toc0_)

# %% [markdown]
# To do EDA, you can use multiple tools, such as:
# + Python libraries: matplotlib, seaborn, plotly, bokeh, etc.
# + Dashboarding software: Tableau, PowerBI, Looker, AWS Quicksight, Dash, etc.
# + The OG of data viz: Excel

# %% [markdown]
# ## <a id='toc5_2_'></a>[Plots / Charts](#toc0_)

# %% [markdown]
# There are many types of plots, but we can group them into:
# + Basic plots:
#     + histograms
#     + box plots
#     + bar plots
#     + ~~pie charts~~
#     + treemap
#     + scatter plots
#     + line plots
#     + heatmaps
#
# + More advanced plots:
#     + violin plots
#     + candlestick chart
#     + lollipop chart
#     + density plot
#     + PCA
#     + ridge plots
#     + ~~3D plots~~
#
# For more plot possibilities, please have a look at [Data-to-viz](https://www.data-to-viz.com/).
#
# *Note:* Please look at pie charts and 3D plots once, then forget they exist.

# %% [markdown]
# ## <a id='toc5_3_'></a>[Methodology](#toc0_)

# %% [markdown]
# The typical process of doing EDA looks something like this:
# + Examining each of the variables for the whole sample (univariate analysis)
# + Examining relationships between >2 variables (bivariate and multivariate analysis)
# + Examining variables across subgroups
# + Re-iterating the previous 3 steps

# %% [markdown]
# Today we'll explore a few of the Python software tools (mainly `matplotlib` and `seaborn`) and the drawing tools (i.e. basic plot types) and next week we will dive into a real EDA process!

# %% [markdown]
# # <a id='toc6_'></a>[Let the EDA begin](#toc0_)

# %% [markdown]
# <iframe src="https://giphy.com/embed/LmHFLSnktq4vK" width="480" height="241" frameBorder="0" class="giphy-embed" allowFullScreen></iframe><p><a href="https://giphy.com/gifs/game-let-begin-LmHFLSnktq4vK">via GIPHY</a></p>

# %%
# Un-comment these if you cannot import the libraries
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
fortune = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/Fortune_1000.csv")
fortune.head()
# Out:
#        company  rank  rank_change   revenue   profit  num. of employees  \
# 0      Walmart     1          0.0  523964.0  14881.0            2200000
# 1       Amazon     2          3.0  280522.0  11588.0             798000
# 2  Exxon Mobil     3         -1.0  264938.0  14340.0              74900
# 3        Apple     4         -1.0  260174.0  55256.0             137000
# 4   CVS Health     5          3.0  256776.0   6634.0             290000
#
#         sector         city state newcomer ceo_founder ceo_woman profitable  \
# 0    Retailing  Bentonville    AR       no          no        no        yes
# 1    Retailing      Seattle    WA       no         yes        no        yes
# 2       Energy       Irving    TX       no          no        no        yes
# 3   Technology    Cupertino    CA       no          no        no        yes
# 4  Health Care   Woonsocket    RI       no          no       yes        yes
#
#   prev_rank                  CEO                        Website Ticker  \
# ...

# %% [markdown]
# *Note:*
# > Market Cap = Market cap—or capitalization—refers to the total value of all a company's shares of stock

# %%
# Check shape
fortune.shape
# Out:
# (1000, 18)

# %%
# Describe numerical dataset
round(fortune.describe())
# Out:
#          rank  rank_change   revenue   profit  num. of employees
# count  1000.0       1000.0    1000.0    998.0             1000.0
# mean    500.0          0.0   15902.0   1345.0            34616.0
# std     289.0         22.0   34763.0   4516.0            92024.0
# min       1.0       -186.0    1990.0  -8506.0               51.0
# 25%     251.0          0.0    3164.0    111.0             6400.0
# 50%     500.0          0.0    5647.0    381.0            13000.0
# 75%     750.0          0.0   12820.0   1061.0            29192.0
# max    1000.0        224.0  523964.0  81417.0          2200000.0

# %%
# Describe categorical columns
fortune.describe(include='object')
# Out:
#         company      sector      city state newcomer ceo_founder ceo_woman  \
# count      1000        1000      1000  1000      500        1000      1000
# unique     1000          21       402    46        2           2         2
# top     Walmart  Financials  New York    CA       no          no        no
# freq          1         162        70   121      477         956       932
#
#        profitable prev_rank                CEO              Website Ticker  \
# count        1000      1000                992                 1000    938
# unique          2       477                989                  999    938
# top           yes            Patricia K. Poppe  https://www.rtx.com    WMT
# freq          854       523                  2                    2      1
#
#        Market Cap
# count         960
# unique        946
# top             -
# freq           10

# %% [markdown]
# ## <a id='toc6_1_'></a>[Histogram](#toc0_)

# %% [markdown]
# Show distribution

# %%
# matplotlib hist
plt.hist(fortune['revenue'], bins=100)
plt.show()

# %%
# seaborn histplot
sns.histplot()
plt.show()

# %%
# plotly express histogram
px.histogram(fortune['revenue'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## <a id='toc6_2_'></a>[Box plot](#toc0_)

# %% [markdown]
# Show quartiles & outliers

# %%
# matplotlib boxplot
# Try profit with NaNs

# %%
# matplotlib boxplot
# Try profit without NaNs

# %%
# matplotlib boxplot
# Try making the chart horizontal

# %%
# seaborn vertical boxplot
sns.boxplot()
plt.show()

# %%
# seaborn horizontal boxplot
sns.boxplot()
plt.show()

# %%
# plotly box horizontal
px.box(x=fortune.profit)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <span style="color:orange">What elements do we see in this box plot?</span>

# %% [markdown]
# We can also have a look at the profit per sector using boxplots!

# %%
sns.boxplot(x=, y=)
plt.show()

# %%
# Too much noise! I will select only a few industries
industries = ['Media', 'Energy', 'Financials', 'Aerospace & Defense']
filtered_fortune = fortune[fortune.sector.isin(industries)]
sns.boxplot(x=, y=)
plt.show()

# %% [markdown]
# ## <a id='toc6_3_'></a>[Bar plots](#toc0_)

# %% [markdown]
# Show amounts & proportions

# %%
# matplotlib requires a bit more work to do bar plots
plt.bar(, height=)
plt.show()

# %%
# For categorical data, seaborn uses catplot
sns.catplot(, x=, kind=)
plt.show()

# %%
# Plotly needs just value_counts

px.bar(fortune['ceo_founder'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Right now we've only seen bar plots to count categorical values but we can also use them to show characteristics of different subgroups. For example, we can see the total profit per sector:

# %%
px.bar(fortune['ceo_founder'].value_counts())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# We'll use a horizontal bar plot instead of a vertical one
plt.barh(, width=)
plt.show()

# %% [markdown]
# So this doesn't make much sense because the bars are everywhere and not really showing us the totals. So we'll do an aggregation instead! What function did we use to aggregate data into different groups?

# %%
# sector profit
sector_profit = fortune.groupby('sector').agg({'profit':'sum'})
fortune.groupby('sector')['profit'].transform('sum')
sector_profit
# Out:
#                                  profit
# sector
# Aerospace & Defense             26134.4
# Apparel                          9019.4
# Business Services               44526.9
# Chemicals                       15806.1
# Energy                          80168.9
# Engineering & Construction       8460.9
# Financials                     415521.9
# Food & Drug Stores               8634.8
# Food, Beverages & Tobacco       46150.1
# Health Care                    154249.4
# Hotels, Restaurants & Leisure   21757.4
# Household Products              11869.6
# Industrials                     33671.7
# Materials                       10326.0
# Media                           24238.7
# Motor Vehicles & Parts           9104.2
# Retailing                       69281.5
# Technology                     273189.9
# Telecommunications              35432.4
# Transportation                  36221.0
# Wholesalers                      8248.2

# %%
# Let's redo the chart
plt.barh(sector_profit.sector, width=sector_profit.profit)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-2587974db65e> in <cell line: 2>()
#       1 # Let's redo the chart
# ----> 2 plt.barh(sector_profit.sector, width=sector_profit.profit)
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'sector'

# %% [markdown]
# Ok, please don't ever leave your plots like this! We need to sort the values in the plot to clearly see the top companies by profit:

# %%
# Sort dataframe & replot

# %% [markdown]
# ## <a id='toc6_4_'></a>[~~Pie charts~~](#toc0_)

# %% [markdown]
# ~~Show proportions~~

# %%
# ceo_founder split in matplotlib
plt.pie(, labels=)
plt.show()

# %%
# Seaborn doesn't have the option to do pie plots

# %%
# Plotly works same as matplotlib
px.pie(values=, names=)

# %%
# Check revenue per sector

# %% [markdown]
# ## Treemap

# %% [markdown]
# A bit more difficult to do in matplotlib than a pie chart but much better. Used to show proportions.

# %%
# !pip install squarify

# %%
import squarify

# %%
volume = fortune.sector.value_counts()
labels = fortune.sector.unique()
plt.rc('font', size=6)
squarify.plot(sizes=volume, label=labels, alpha=0.7, color=list(sns.color_palette('Paired')))
plt.axis('off')
plt.show()

# %%
fortune.sector.value_counts().sort_values(ascending=False)[:10]

# %%
# Select only top industries - how do I do that?
volume = fortune.sector.value_counts()
labels = fortune.sector.value_counts().index
plt.rc('font', size=6)
squarify.plot(sizes=volume, label=labels, alpha=0.7, color=list(sns.color_palette('Paired')))
plt.axis('off')
plt.show()

# %% [markdown]
# Check out the seaborn color palette:

# %%
sns.color_palette('Paired')

# %% [markdown]
# ## <a id='toc6_5_'></a>[Scatter plot](#toc0_)

# %% [markdown]
# Show potential correlations

# %%
# matplotlib
plt.scatter(fortune.profit, fortune.revenue)
plt.show()

# %% [markdown]
# ## <a id='toc6_6_'></a>[Line plot](#toc0_)

# %% [markdown]
# Show trends - typically used with time series

# %%
# Run this before the next cell
# !pip install yfinance

# %%
# Don't worry about this too much, I'm just interested in getting a time series
import yfinance as yf
import datetime as dt
amazon = yf.Ticker('AMZN')
amazon_data = amazon.history(start='2022-01-01', end=dt.date.today())
amazon_data.head()

# %%
# Default plot in matplotlib is a line plot
plt.plot(amazon_data.index, amazon_data.Open)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Don't use instead of scatterplots!

# %%
# matplotlib
plt.plot(fortune.profit, fortune.revenue)
plt.show()

# %% [markdown]
# I cannot get any information from this plot because it's simply connecting the dots from the scatterplot!

# %% [markdown]
# ## <a id='toc6_7_'></a>[💡 Check for understanding](#toc0_)

# %% [markdown]
# You will still be working with the Fortune 1000 dataset like last time but this time you will visualize the results!

# %%
fortune = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/Fortune_1000.csv")
fortune.sample(10)
# Out:
#                      company  rank  rank_change  revenue   profit  \
# 82          General Dynamics    83          9.0  39350.0   3484.0
# 811               AptarGroup   812          0.0   2859.7    242.2
# 135  Penske Automotive Group   136          0.0  23179.4    435.8
# 442               CMS Energy   443         -3.0   6845.0    680.0
# 136                     Visa   137         16.0  22977.0  12080.0
# 646       Diamondback Energy   647          0.0   3964.0    240.0
# 919                    TEGNA   920          0.0   2299.5    286.2
# 939                  Groupon   940          0.0   2218.9    -22.4
# 284                    Adobe   285         54.0  11171.3   2951.5
# 982   Floor & Decor Holdings   983          0.0   2045.5    150.6
#
#      num. of employees               sector              city state newcomer  \
# 82              102900  Aerospace & Defense            Reston    VA       no
# 811              14000            Materials      Crystal Lake    IL      NaN
# ...

# %% [markdown]
# **Questions**
# - Show the number of different companies per sector with an appropriate chart. Do the same for state.
# - Show the relative proportion of sectors in the dataset with an appropriate chart. Do the same for state.
# - Can you do the same to check the overall revenue per sector?
# - Check the distribution of market cap for the companies in the dataset. What do you see?
# - Are there many outlier companies when looking at market cap? Choose an appropriate graph to show this.
# - Display the number of companies per sector for the top 10% of companies. Do the same for the bottom 10%.
# - Check how profit changes in relationship to revenue with an appropriate plot. Do the same for market cap. What do you see?
# - Lastly, have a look at the sectors that have female CEOs. Which one is the most prevalent?
# - What new information did we get through EDA compared to last time? Feel free to look for other things as well 😉
#
# *Notes:*
# - You might need to remove NaNs from some of the columns!
# - You might need to convert the `Market Cap` data type to numerical using `pd.to_numeric()`!

# %%
px.bar(fortune)

# %%
import plotly.express as px
sector_company = fortune.groupby('sector').agg({'company':'count'}).reset_index().sort_values(by='company')
fig = px.bar(sector_company, x='sector', y='company')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sector_revenue = fortune.groupby('sector').agg({'revenue':'sum'}).reset_index().sort_values(by='revenue', ascending=False )
fig = px.bar(sector_revenue, x='sector', y='revenue')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fortune.revenue.quantile(0.9)

# %%
top_ten = fortune[fortune['revenue'] > fortune.revenue.quantile(0.9)]
top_ten_company_number = top_ten.sector.value_counts()
fig = px.bar(top_ten_company_number)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_ten_company_number
# Out:
# Financials                   24
# Health Care                  14
# Energy                       10
# Technology                   10
# Retailing                     8
# Transportation                5
# Aerospace & Defense           5
# Food, Beverages & Tobacco     4
# Industrials                   4
# Food & Drug Stores            4
# Telecommunications            4
# Motor Vehicles & Parts        2
# Wholesalers                   2
# Media                         1
# Household Products            1
# Chemicals                     1
# Apparel                       1
# Name: sector, dtype: int64

# %% [markdown]
# ## <a id='toc6_8_'></a>[Common mistakes!](#toc0_)

# %%
import plotly.express as px
customer_data = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv")

# %% [markdown]
# ### <a id='toc6_8_1_'></a>[Plotting without understanding what you're plotting (e.g. `customer_id`)](#toc0_)

# %%
px.bar(customer_data, x='Customer')

# %% [markdown]
# This graph doesn't give us any significant information. It just shows the number of claims per customer but it's too cluttered to read.

# %% [markdown]
# ### <a id='toc6_8_2_'></a>[Doing barplots for numerical continuous data](#toc0_)

# %%
sns.barplot(customer_data, y='Income')

# %% [markdown]
# ### <a id='toc6_8_3_'></a>[Doing boxplots for numerical discrete data](#toc0_)

# %%
px.box(customer_data, x='Number of Open Complaints')

# %% [markdown]
# ### <a id='toc6_8_4_'></a>[Considering histograms on numerical discrete data as normal distributions](#toc0_)

# %%
sns.displot(customer_data, x='Number of Open Complaints')

# %% [markdown]
# ### <a id='toc6_8_5_'></a>[Creating noisy plots](#toc0_)

# %%
sns.boxplot(customer_data, x='Effective To Date', y='Total Claim Amount')
plt.show()

# %% [markdown]
# You can make the plot wider!!!

# %%
# Matplotlib and Seaborn can work together
fig, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(customer_data, x='Effective To Date', y='Total Claim Amount')
plt.xticks(rotation=45)
plt.show()

# %%
# Or use plotly (and hover for details)
px.box(customer_data, x='Effective To Date', y='Total Claim Amount')
